# %% [markdown]
# Deep Learning
# =============
#
# Assignment 5
# ------------
#
# The goal of this assignment is to train a Word2Vec skip-gram model over [Text8](http://mattmahoney.net/dc/textdata) data.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
# %matplotlib inline
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE

# %% [markdown]
# Download the data from the source website if necessary.

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
    """Download a file if not present, and make sure it's the right size."""
    if not os.path.exists(filename):
        filename, _ = urlretrieve(url + filename, filename)
    statinfo = os.stat(filename)
    if statinfo.st_size == expected_bytes:
        print('Found and verified %s' % filename)
    else:
        print(statinfo.st_size)
        raise Exception(
      'Failed to verify ' + filename + '. Can you get to it with a browser?')
    return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %% [markdown]
# Read the data into a string.

# %%
def read_data(filename):
    """Extract the first file enclosed in a zip file as a list of words"""
    with zipfile.ZipFile(filename) as f:
        data = tf.compat.as_str(f.read(f.namelist()[0])).split()
    return data
  
words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %% [markdown]
# Build the dictionary and replace rare words with UNK token.

# %%
vocabulary_size = 50000

def build_dataset(words):
    count = [['UNK', -1]]
    count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
    dictionary = dict()
    for word, _ in count:
        dictionary[word] = len(dictionary)
    data = list()
    unk_count = 0
    for word in words:
        if word in dictionary:
            index = dictionary[word]
        else:
            index = 0  # dictionary['UNK']
            unk_count = unk_count + 1
        data.append(index)
    count[0][1] = unk_count
    reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
    return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)
print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5238, 3084, 12, 6, 195, 2, 3135, 46, 59, 156]

# %% [markdown]
# Let's display the internal variables to better understand their structure:

# %%
print(data[:10])
print(count[:10])
print(list(dictionary.items())[:10])
print(list(reverse_dictionary.items())[:10])
# Out:
# [5238, 3084, 12, 6, 195, 2, 3135, 46, 59, 156]
# [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764), ('in', 372201), ('a', 325873), ('to', 316376), ('zero', 264975), ('nine', 250430)]
# [('charleston', 11543), ('frg', 35487), ('specialisation', 43467), ('rotterdam', 17520), ('hyperbolic', 14671), ('cynicism', 27042), ('masts', 28123), ('greve', 45873), ('cheeses', 10814), ('counterattack', 28124)]
# [(0, 'UNK'), (1, 'the'), (2, 'of'), (3, 'and'), (4, 'one'), (5, 'in'), (6, 'a'), (7, 'to'), (8, 'zero'), (9, 'nine')]

# %% [markdown]
# Function to generate a training batch for the skip-gram model.

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
    global data_index
    assert batch_size % num_skips == 0
    assert num_skips <= 2 * skip_window
    batch = np.ndarray(shape=(batch_size), dtype=np.int32)
    labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
    span = 2 * skip_window + 1 # [ skip_window target skip_window ]
    buffer = collections.deque(maxlen=span)
    for _ in range(span):
        buffer.append(data[data_index])
        data_index = (data_index + 1) % len(data)
    for i in range(batch_size // num_skips):
        target = skip_window  # target label at the center of the buffer
        targets_to_avoid = [ skip_window ]
        for j in range(num_skips):
            while target in targets_to_avoid:
                target = random.randint(0, span - 1)
            targets_to_avoid.append(target)
            batch[i * num_skips + j] = buffer[skip_window]
            labels[i * num_skips + j, 0] = buffer[target]
        buffer.append(data[data_index])
        data_index = (data_index + 1) % len(data)
    return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:32]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=16, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(16)])
    
for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 1
    batch, labels = generate_batch(batch_size=16, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(16)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the', 'diggers', 'of', 'the', 'english', 'revolution', 'and', 'the', 'sans', 'UNK', 'of', 'the', 'french', 'revolution', 'whilst', 'the', 'term']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term', 'of', 'of', 'abuse', 'abuse', 'first', 'first', 'used', 'used']
#     labels: ['anarchism', 'as', 'a', 'originated', 'term', 'as', 'a', 'of', 'term', 'abuse', 'first', 'of', 'abuse', 'used', 'against', 'first']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a', 'term', 'term', 'term', 'term', 'of', 'of', 'of', 'of']
#     labels: ['originated', 'anarchism', 'a', 'term', 'originated', 'of', 'as', 'term', 'as', 'abuse', 'of', 'a', 'abuse', 'a', 'first', 'term']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['as', 'as', 'a', 'a', 'term', 'term', 'of', 'of', 'abuse', 'abuse', 'first', 'first', 'used', 'used', 'against', 'against']
#     labels: ['a', 'originated', 'term', 'as', 'of', 'a', 'term', 'abuse', 'of', 'first', 'used', 'abuse', 'against', 'first', 'used', 'early']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['a', 'a', 'a', 'a', 'term', 'term', 'term', 'term', 'of', 'of', 'of', 'of', 'abuse', 'abuse', 'abuse', 'abuse']
#     labels: ['of', 'originated', 'as', 'term', 'a', 'as', 'of', 'abuse', 'a', 'term', 'abuse', 'first', 'term', 'used', 'first', 'of']

# %% [markdown]
# Note: the labels is a sliding random value of the word surrounding the words of the batch.

# %% [markdown]
# It is not obvious with the output above, but all the data are based on index, and not the word directly.

# %%
print(batch)
print(labels)
# Out:
# [   6    6    6    6  195  195  195  195    2    2    2    2 3135 3135 3135
#  3135]
# [[   2]
#  [3084]
#  [  12]
#  [ 195]
#  [   6]
#  [  12]
#  [   2]
#  [3135]
#  [   6]
#  [ 195]
#  [3135]
#  [  46]
#  [ 195]
#  [  59]
#  [  46]
#  [   2]]

# %% [markdown]
# Train a skip-gram model.

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):
    
    # Input data.
    train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
    train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
    # Variables.
    embeddings = tf.Variable(
      tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
    softmax_weights = tf.Variable(
      tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
    softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
    # Model.
    # Look up embeddings for inputs.
    embed = tf.nn.embedding_lookup(embeddings, train_dataset)
    # Compute the softmax loss, using a sample of the negative labels each time.
    loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(softmax_weights, softmax_biases, embed,
                               train_labels, num_sampled, vocabulary_size))

    # Optimizer.
    optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
    # Compute the similarity between minibatch examples and all embeddings.
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
    normalized_embeddings = embeddings / norm
    valid_embeddings = tf.nn.embedding_lookup(
      normalized_embeddings, valid_dataset)
    similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
    tf.initialize_all_variables().run()
    print('Initialized')
    average_loss = 0
    for step in range(num_steps):
        batch_data, batch_labels = generate_batch(
      batch_size, num_skips, skip_window)
        feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
        _, l = session.run([optimizer, loss], feed_dict=feed_dict)
        average_loss += l
        if step % 2000 == 0:
            if step > 0:
                average_loss = average_loss / 2000
            # The average loss is an estimate of the loss over the last 2000 batches.
            print('Average loss at step %d: %f' % (step, average_loss))
            average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
        if step % 10000 == 0:
            sim = similarity.eval()
            for i in range(valid_size):
                valid_word = reverse_dictionary[valid_examples[i]]
                top_k = 8 # number of nearest neighbors
                nearest = (-sim[i, :]).argsort()[1:top_k+1]
                log = 'Nearest to %s:' % valid_word
                for k in range(top_k):
                    close_word = reverse_dictionary[nearest[k]]
                    log = '%s %s,' % (log, close_word)
                print(log)
    final_embeddings = normalized_embeddings.eval()
# Out:
# WARNING:tensorflow:From <ipython-input-14-3ec224cebaff>:4 in <module>.: initialize_all_variables (from tensorflow.python.ops.variables) is deprecated and will be removed after 2017-03-02.
# Instructions for updating:
# Use `tf.global_variables_initializer` instead.
# Initialized
# Average loss at step 0: 8.272306
# Nearest to can: snobol, ij, silverberg, bracken, qualifiers, orissa, classified, ils,
# Nearest to this: nanoscale, dribble, ezquerra, bmj, rightness, provisionally, lincolnshire, graphite,
# Nearest to has: hysterical, shaken, southwest, domed, attila, kahan, secrete, candid,
# Nearest to so: aswan, interplay, bali, wissenschaften, original, ak, monmouth, cushing,
# Nearest to seven: vader, gypsum, insulating, logitech, halts, ban, dues, farley,
# Nearest to be: film, enrico, conde, years, tucum, symbolising, vfl, influx,
# Nearest to in: vent, blasts, warplanes, defamation, subversive, remo, discus, tomorrow,
# Nearest to two: leontopithecus, earhart, hermitian, uneconomic, vms, concord, lamellar, martyred,
# Nearest to have: baresi, donaghy, ranging, refugees, splendor, bishkek, citric, northwestern,
# Nearest to an: penalty, blaxploitation, peninsular, sans, conjectural, resumed, dismounted, multiply,
# Nearest to that: ballparks, amino, spiked, existential, diploid, mobilization, protagoras, seasonal,
# Nearest to is: bartleby, lucretia, ibizan, uriah, ethnocentrism, fiendish, ten, prevention,
# Nearest to most: lockhart, helga, meson, entrance, descent, sutter, ruptured, industrialised,
# Nearest to of: sds, pvp, climatology, homeopaths, unknown, ariadne, danse, christadelphians,
# Nearest to a: fourteen, gifford, downgraded, inherits, hospitals, enthusiasm, kitts, chico,
# Nearest to were: salish, astute, investigative, spouse, plo, allophonic, psychotherapy, appeasement,
# Average loss at step 2000: 4.368304
# Average loss at step 4000: 3.862447
# Average loss at step 6000: 3.788696
# Average loss at step 8000: 3.680182
# Average loss at step 10000: 3.609192
# Nearest to can: may, would, will, must, should, michelin, mate, is,
# Nearest to this: which, the, it, jalal, herzog, prefixed, that, necronomicon,
# Nearest to has: had, have, was, is, posthumus, siberian, bankrupted, mmol,
# Nearest to so: aswan, bali, wissenschaften, monmouth, scientists, holbein, mandelbrot, not,
# Nearest to seven: six, eight, three, five, nine, four, zero, two,
# Nearest to be: have, is, adopting, been, spheres, was, shenzhen, become,
# Nearest to in: of, on, from, with, subversive, westphalia, after, during,
# Nearest to two: five, four, three, seven, six, eight, nine, one,
# Nearest to have: has, be, had, are, were, donaghy, ahijah, dalnet,
# Nearest to an: sans, the, troilus, cid, galatians, partita, resumed, penalty,
# Nearest to that: which, it, kept, existential, this, there, dotted, summaries,
# Nearest to is: was, are, has, golovachev, be, were, turrets, by,
# Nearest to most: ruptured, sutter, epitomized, nature, afrikaans, tl, lockhart, nitrile,
# Nearest to of: in, same, kramer, and, chalker, cornelia, mate, for,
# Nearest to a: the, any, pyruvate, bulgars, rhea, fourteen, adapt, bajan,
# Nearest to were: are, salish, was, have, marriageable, is, plo, snk,
# Average loss at step 12000: 3.611100
# Average loss at step 14000: 3.567490
# Average loss at step 16000: 3.410837
# Average loss at step 18000: 3.460725
# Average loss at step 20000: 3.538547
# Nearest to can: may, would, will, must, should, could, to, cannot,
# Nearest to this: which, it, herzog, the, a, his, cyclopedia, that,
# Nearest to has: had, have, was, is, dalnet, siberian, posthumus, having,
# Nearest to so: bali, scientists, wissenschaften, monmouth, aswan, yet, renamed, interplay,
# Nearest to seven: six, eight, nine, five, four, three, zero, two,
# Nearest to be: have, been, was, is, adopting, were, by, become,
# Nearest to in: on, at, with, from, by, and, during, subversive,
# Nearest to two: three, four, five, six, one, seven, eight, nine,
# Nearest to have: had, has, be, were, are, donaghy, splendor, latvia,
# Nearest to an: the, troilus, liquefaction, sans, partita, sixes, spiral, samantha,
# Nearest to that: which, but, who, this, kept, camphor, circumcision, locates,
# Nearest to is: was, has, are, if, but, be, were, adopting,
# Nearest to most: ruptured, more, sutter, epitomized, nature, tl, afrikaans, smilga,
# Nearest to of: parrot, for, same, berber, boc, observational, salvatore, incommunicado,
# Nearest to a: any, the, this, fourteen, no, wynette, bulgars, another,
# Nearest to were: are, was, had, have, diversification, while, and, salish,
# Average loss at step 22000: 3.505124
# Average loss at step 24000: 3.487983
# Average loss at step 26000: 3.481509
# Average loss at step 28000: 3.483149
# Average loss at step 30000: 3.502908
# Nearest to can: may, would, will, could, must, should, cannot, to,
# Nearest to this: which, it, that, there, jalal, plowing, cyclopedia, some,
# Nearest to has: had, have, is, was, having, posthumus, since, franks,
# Nearest to so: bali, stafford, yet, wissenschaften, monmouth, sexy, breeds, scientists,
# Nearest to seven: eight, nine, five, six, four, three, zero, one,
# Nearest to be: have, is, been, was, javelin, shenzhen, backstage, refer,
# Nearest to in: during, of, on, under, at, from, mithras, and,
# Nearest to two: three, four, one, five, eight, seven, six, nine,
# Nearest to have: had, has, were, be, are, having, preserve, continue,
# Nearest to an: partita, liquefaction, troilus, spiral, unrounded, sixes, kordofanian, frameworks,
# Nearest to that: which, this, circumcision, what, but, besieged, colonial, who,
# Nearest to is: was, has, are, be, became, paint, did, but,
# Nearest to most: more, ruptured, some, smilga, nature, epitomized, tl, sutter,
# Nearest to of: in, and, for, from, parrot, logician, starved, dah,
# Nearest to a: any, the, his, whisper, systematically, their, no, arbiter,
# Nearest to were: are, was, have, had, while, loan, by, those,
# Average loss at step 32000: 3.502340
# Average loss at step 34000: 3.492656
# Average loss at step 36000: 3.458335
# Average loss at step 38000: 3.298368
# Average loss at step 40000: 3.421349
# Nearest to can: may, will, could, would, must, should, cannot, might,
# Nearest to this: which, it, the, that, corsica, he, cyclopedia, baserunner,
# Nearest to has: had, have, was, is, having, since, franks, governorates,
# Nearest to so: stafford, proton, bali, breeds, not, sexy, more, yet,
# Nearest to seven: eight, nine, five, six, four, three, zero, one,
# Nearest to be: have, been, is, were, are, whistle, refer, adopting,
# Nearest to in: and, of, during, at, for, instinct, within, to,
# Nearest to two: three, four, five, six, seven, one, eight, nine,
# Nearest to have: had, has, were, be, are, preserve, having, nontraditional,
# Nearest to an: troilus, liquefaction, sans, samantha, partita, frameworks, disbanded, earthquakes,
# Nearest to that: which, this, what, autodesk, however, cahill, where, addressing,
# Nearest to is: was, has, are, if, be, golovachev, helsing, when,
# Nearest to most: more, khoi, smilga, ruptured, memoir, some, epitomized, nature,
# Nearest to of: in, like, salvatore, cornelia, mcgrath, kramer, for, irr,
# Nearest to a: the, descriptive, pyruvate, scare, provisioning, omari, any, another,
# Nearest to were: are, have, was, had, when, be, been, loan,
# Average loss at step 42000: 3.439033
# Average loss at step 44000: 3.450460
# Average loss at step 46000: 3.445159
# Average loss at step 48000: 3.354825
# Average loss at step 50000: 3.381650
# Nearest to can: may, could, will, would, must, should, cannot, might,
# Nearest to this: which, it, instead, the, some, itself, he, embroidery,
# Nearest to has: had, have, was, is, since, having, governorates, witted,
# Nearest to so: intruders, binghamton, stafford, proton, she, then, fossilized, equivalently,
# Nearest to seven: eight, six, nine, four, three, five, zero, two,
# Nearest to be: have, been, was, provide, refer, become, were, is,
# Nearest to in: during, of, on, within, from, under, and, since,
# Nearest to two: three, four, one, six, five, eight, seven, nine,
# Nearest to have: had, has, were, are, be, having, continue, who,
# Nearest to an: liquefaction, amf, samantha, partita, troilus, frameworks, kordofanian, sixes,
# Nearest to that: which, however, what, circumcision, examinations, cleves, besieged, gemstones,
# Nearest to is: was, has, are, contains, became, includes, be, parr,
# Nearest to most: more, smilga, some, khoi, ruptured, many, fyodorovna, throughout,
# Nearest to of: in, and, including, from, ieee, irr, berber, for,
# Nearest to a: another, the, bulgars, assays, whisper, any, streamline, lusatia,
# Nearest to were: are, have, was, had, those, be, adopting, being,
# Average loss at step 52000: 3.435159
# Average loss at step 54000: 3.425417
# Average loss at step 56000: 3.436336
# Average loss at step 58000: 3.394980
# Average loss at step 60000: 3.390914
# Nearest to can: may, would, could, will, must, should, cannot, might,
# Nearest to this: which, it, that, there, the, itself, plowing, some,
# Nearest to has: had, have, was, is, having, governorates, northwestern, posthumus,
# Nearest to so: proton, then, binghamton, even, stafford, fossilized, remark, intruders,
# Nearest to seven: eight, six, nine, four, five, three, zero, two,
# Nearest to be: been, is, was, refer, have, prove, are, whistle,
# Nearest to in: during, including, within, of, with, on, from, since,
# Nearest to two: three, four, five, six, eight, seven, one, zero,
# Nearest to have: has, had, were, are, include, preserve, having, criminality,
# Nearest to an: liquefaction, troilus, sixes, beelzebub, amf, frameworks, partita, samantha,
# Nearest to that: which, this, what, however, where, it, gemstones, cleves,
# Nearest to is: was, are, be, has, contains, although, if, makes,
# Nearest to most: more, many, some, smilga, use, locksmiths, afrikaans, khoi,
# Nearest to of: in, casein, including, ieee, incommunicado, or, for, fisc,
# Nearest to a: any, the, another, pyruvate, systematically, this, every, fourteen,
# Nearest to were: are, have, those, was, had, many, maximally, although,
# Average loss at step 62000: 3.237459
# Average loss at step 64000: 3.254445
# Average loss at step 66000: 3.407773
# Average loss at step 68000: 3.396617
# Average loss at step 70000: 3.359674
# Nearest to can: may, could, would, will, must, should, cannot, might,
# Nearest to this: which, it, the, that, what, itself, some, lawlessness,
# Nearest to has: had, have, was, is, since, nicosia, having, karaca,
# Nearest to so: then, fossilized, stafford, aqueous, senseless, proton, later, miscarriages,
# Nearest to seven: eight, six, four, nine, five, three, zero, two,
# Nearest to be: been, is, were, was, have, being, become, are,
# Nearest to in: within, during, at, on, with, lurking, between, for,
# Nearest to two: three, four, six, seven, one, five, eight, zero,
# Nearest to have: had, has, were, are, include, be, preserve, having,
# Nearest to an: troilus, liquefaction, sixes, frameworks, earthquakes, kordofanian, cracked, beelzebub,
# Nearest to that: which, however, what, this, where, but, typically, circumcision,
# Nearest to is: was, has, are, be, seems, does, became, contains,
# Nearest to most: more, many, smilga, some, less, use, because, throughout,
# Nearest to of: including, parrot, and, casein, include, dorians, usk, like,
# Nearest to a: another, the, any, signaling, civ, provisioning, gard, kling,
# Nearest to were: are, was, have, had, be, those, been, dcs,
# Average loss at step 72000: 3.370882
# Average loss at step 74000: 3.346762
# Average loss at step 76000: 3.310879
# Average loss at step 78000: 3.345812
# Average loss at step 80000: 3.373847
# Nearest to can: could, may, will, would, must, should, cannot, might,
# Nearest to this: which, it, plowing, itself, what, some, the, there,
# Nearest to has: had, have, is, was, since, having, horticulture, governorates,
# Nearest to so: then, before, fossilized, later, stafford, proton, aqueous, however,
# Nearest to seven: six, five, eight, four, nine, three, zero, two,
# Nearest to be: been, refer, have, prove, become, being, provide, is,
# Nearest to in: within, during, on, since, at, until, under, of,
# Nearest to two: three, six, four, five, seven, one, eight, nine,
# Nearest to have: had, has, are, were, include, preserve, contain, be,
# Nearest to an: liquefaction, troilus, kordofanian, sans, sixes, frameworks, passwords, samantha,
# Nearest to that: which, however, where, what, but, harman, this, circumcision,
# Nearest to is: was, has, are, seems, modular, became, astounding, contains,
# Nearest to most: more, many, some, less, especially, smilga, because, plebiscite,
# Nearest to of: in, including, zoroaster, under, parrot, observational, faithless, original,
# Nearest to a: another, the, whisper, arbiter, pyruvate, proselytizing, signaling, lahoud,
# Nearest to were: are, had, have, was, although, those, nei, being,
# Average loss at step 82000: 3.409090
# Average loss at step 84000: 3.409457
# Average loss at step 86000: 3.390920
# Average loss at step 88000: 3.353410
# Average loss at step 90000: 3.366075
# Nearest to can: could, may, will, would, must, should, might, cannot,
# Nearest to this: it, which, itself, the, tte, plowing, some, wycliffe,
# Nearest to has: had, have, is, was, having, governorates, since, fb,
# Nearest to so: before, later, then, stafford, kelvin, if, proton, salvatore,
# Nearest to seven: eight, six, nine, five, four, three, zero, one,
# Nearest to be: been, prove, have, was, refer, being, become, provide,
# Nearest to in: during, within, under, alerts, between, of, near, and,
# Nearest to two: three, five, four, six, seven, eight, one, nine,
# Nearest to have: had, has, were, are, contain, include, be, having,
# Nearest to an: troilus, liquefaction, kordofanian, sixes, amf, quaternion, frameworks, sans,
# Nearest to that: which, however, what, examinations, cleves, gemstones, instead, but,
# Nearest to is: was, has, are, does, although, cigarette, involves, refers,
# Nearest to most: more, many, all, some, less, throughout, smilga, because,
# Nearest to of: including, for, salvatore, in, parrot, ieee, exact, include,
# Nearest to a: another, any, every, jenner, quebecers, the, no, pyruvate,
# Nearest to were: are, had, was, while, have, been, being, those,
# Average loss at step 92000: 3.398528
# Average loss at step 94000: 3.253049
# Average loss at step 96000: 3.355649
# Average loss at step 98000: 3.237454
# Average loss at step 100000: 3.361021
# Nearest to can: may, could, will, must, would, should, cannot, might,
# Nearest to this: which, it, itself, another, some, plowing, what, he,
# Nearest to has: had, have, is, was, having, since, unwin, governorates,
# Nearest to so: stafford, then, later, proton, before, kelvin, if, what,
# Nearest to seven: eight, nine, four, six, five, three, zero, two,
# Nearest to be: prove, is, been, have, refer, are, become, being,
# Nearest to in: during, within, at, until, on, from, among, throughout,
# Nearest to two: four, three, five, six, one, seven, eight, zero,
# Nearest to have: had, has, contain, are, were, be, wish, include,
# Nearest to an: troilus, liquefaction, frameworks, passwords, tractor, sixes, kordofanian, reserved,
# Nearest to that: which, what, however, gemstones, cleves, actually, often, examinations,
# Nearest to is: was, has, be, refers, seems, became, are, becomes,
# Nearest to most: more, less, many, some, especially, use, all, particularly,
# Nearest to of: including, and, observational, zoroaster, in, parrot, original, protista,
# Nearest to a: another, any, the, homilies, systematically, bulgars, enough, austrasia,
# Nearest to were: are, was, have, these, had, those, include, saccharomyces,

# %% [markdown]
# This is what an embedding looks like:

# %%
print(final_embeddings[0])
# Out:
# [-0.02344164 -0.0288946   0.02196527  0.07266057 -0.10059112  0.09962116
#  -0.04448842 -0.1044748   0.05087186  0.02835871  0.1375728   0.06472556
#  -0.03118435  0.01582744  0.04639987  0.06370745 -0.01976574 -0.03694236
#   0.09190218 -0.09643115 -0.03312184  0.08288894 -0.06865048  0.02055587
#  -0.04059112  0.06518398  0.1162034  -0.12675722  0.04742119 -0.04646587
#   0.05922562  0.08453401 -0.06880302 -0.02396173  0.02331211 -0.13311617
#   0.01217951  0.15021309 -0.00048844 -0.10134812  0.06143981  0.12262745
#   0.02828087 -0.08313069 -0.13611138  0.10632557  0.0181899  -0.09644527
#   0.06271365 -0.03152015  0.18898974  0.02271893  0.03869289  0.03456029
#  -0.1041303  -0.01189159  0.13306126 -0.09433408 -0.19040385 -0.08361279
#  -0.11202162 -0.19270816 -0.02192874 -0.05026037  0.07621656  0.0106075
#   0.09315425  0.19780724  0.0455717  -0.01091172 -0.04705461 -0.09393863
#  -0.05780801  0.08743018  0.12072095  0.02959083  0.08538008  0.08886983
#   0.08772211  0.08545946  0.03928091 -0.11424247  0.06499022 -0.07771758
#   0.08325008 -0.04262739  0.14169896  0.05719547 -0.21012634 -0.00261206
#  -0.03131424  0.04133331 -0.03518264 -0.10027336 -0.01492367  0.18838809
#   0.11273988 -0.01422684 -0.09273169 -0.08007994  0.04897843  0.02591263
#  -0.09161457 -0.12629953  0.11669293 -0.02518058 -0.00640871  0.10380446
#  -0.0807107  -0.08839009 -0.02980153 -0.21668544 -0.04737641 -0.01061895
#   0.10634843  0.01210653 -0.08023583  0.08057253  0.12233464 -0.0068393
#  -0.016647    0.0436306   0.10043405 -0.07615005 -0.12191409  0.14687625
#   0.14667282  0.09046122]

# %% [markdown]
# All the values are abstract, there is practical meaning of the them. Moreover, the final embeddings are normalized as you can see here:

# %%
print(np.sum(np.square(final_embeddings[0])))
# Out:
# 1.0

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
    assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
    pylab.figure(figsize=(15,15))  # in inches
    for i, label in enumerate(labels):
        x, y = embeddings[i,:]
        pylab.scatter(x, y)
        pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
    pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)

# %% [markdown]
# ---
#
# Problem
# -------
#
# An alternative to skip-gram is another Word2Vec model called [CBOW](http://arxiv.org/abs/1301.3781) (Continuous Bag of Words). In the CBOW model, instead of predicting a context word from a word vector, you predict a word from the sum of all the word vectors in its context. Implement and evaluate a CBOW model trained on the text8 dataset.
#
# ---

# %% [markdown]
# For the continuous bag of words, the train inputs are slightly different from the skip-gram:

# %%
data_index = 0

def generate_batch(batch_size, bag_window):
    global data_index
    span = 2 * bag_window + 1 # [ bag_window target bag_window ]
    batch = np.ndarray(shape=(batch_size, span - 1), dtype=np.int32)
    labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)  
    buffer = collections.deque(maxlen=span)
    for _ in range(span):
        buffer.append(data[data_index])
        data_index = (data_index + 1) % len(data)
    for i in range(batch_size):
        # just for testing
        buffer_list = list(buffer)
        labels[i, 0] = buffer_list.pop(bag_window)
        batch[i] = buffer_list
        # iterate to the next buffer
        buffer.append(data[data_index])
        data_index = (data_index + 1) % len(data)
    return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:16]])

for bag_window in [1, 2]:
    data_index = 0
    batch, labels = generate_batch(batch_size=4, bag_window=bag_window)
    print('\nwith bag_window = %d:' % (bag_window))  
    print('    batch:', [[reverse_dictionary[w] for w in bi] for bi in batch])  
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(4)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the']
#
# with bag_window = 1:
#     batch: [['anarchism', 'as'], ['originated', 'a'], ['as', 'term'], ['a', 'of']]
#     labels: ['originated', 'as', 'a', 'term']
#
# with bag_window = 2:
#     batch: [['anarchism', 'originated', 'a', 'term'], ['originated', 'as', 'term', 'of'], ['as', 'a', 'of', 'abuse'], ['a', 'term', 'abuse', 'first']]
#     labels: ['as', 'a', 'term', 'of']

# %% [markdown]
# Note the instruction change on the loss function, with ``reduce_sum`` to sum the word vectors in the context:

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
###skip_window = 1 # How many words to consider left and right.
###num_skips = 2 # How many times to reuse an input to generate a label.
bag_window = 2 # How many words to consider left and right.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

    # Input data.
    train_dataset = tf.placeholder(tf.int32, shape=[batch_size, bag_window * 2])
    train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
    # Variables.
    embeddings = tf.Variable(
      tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
    softmax_weights = tf.Variable(
      tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
    softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
    # Model.
    # Look up embeddings for inputs.
    embeds = tf.nn.embedding_lookup(embeddings, train_dataset)
    # Compute the softmax loss, using a sample of the negative labels each time.
    loss = tf.reduce_mean(
      tf.nn.sampled_softmax_loss(softmax_weights, softmax_biases, tf.reduce_sum(embeds, 1),
                               train_labels, num_sampled, vocabulary_size))

    # Optimizer.
    optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
    # Compute the similarity between minibatch examples and all embeddings.
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
    normalized_embeddings = embeddings / norm
    valid_embeddings = tf.nn.embedding_lookup(
      normalized_embeddings, valid_dataset)
    similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
    tf.initialize_all_variables().run()
    print('Initialized')
    average_loss = 0
    for step in range(num_steps):
        batch_data, batch_labels = generate_batch(
          batch_size, bag_window)
        feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
        _, l = session.run([optimizer, loss], feed_dict=feed_dict)
        average_loss += l
        if step % 2000 == 0:
            if step > 0:
                average_loss = average_loss / 2000
            # The average loss is an estimate of the loss over the last 2000 batches.
            print('Average loss at step %d: %f' % (step, average_loss))
            average_loss = 0
        # note that this is expensive (~20% slowdown if computed every 500 steps)
        if step % 10000 == 0:
            sim = similarity.eval()
            for i in range(valid_size):
                valid_word = reverse_dictionary[valid_examples[i]]
                top_k = 8 # number of nearest neighbors
                nearest = (-sim[i, :]).argsort()[1:top_k+1]
                log = 'Nearest to %s:' % valid_word
                for k in range(top_k):
                    close_word = reverse_dictionary[nearest[k]]
                    log = '%s %s,' % (log, close_word)
                print(log)
    final_embeddings = normalized_embeddings.eval()
# Out:
# WARNING:tensorflow:From <ipython-input-21-77d264d3cc79>:4 in <module>.: initialize_all_variables (from tensorflow.python.ops.variables) is deprecated and will be removed after 2017-03-02.
# Instructions for updating:
# Use `tf.global_variables_initializer` instead.
# Initialized
# Average loss at step 0: 8.193207
# Nearest to years: discovery, dickinson, formations, lass, yeshiva, scripture, exocet, reads,
# Nearest to during: neurology, susan, neoplatonic, aosta, religionfacts, philippe, cadr, kingfisher,
# Nearest to used: rejected, cnidaria, demeanor, wasteful, midfielders, lizzie, nom, curious,
# Nearest to he: artery, agrarianism, grabbed, equated, apatosaurus, frontiers, brotherhood, monica,
# Nearest to five: launching, mushrooms, moxie, definitional, thule, extracting, wearable, sie,
# Nearest to no: teleplay, organic, contesting, hyperfocal, dripping, definite, dionysius, recite,
# Nearest to and: dame, broadcasters, howl, ditka, sm, underpinnings, triglycerides, remixed,
# Nearest to use: provocation, wallenberg, we, dlr, azerbaijan, danios, instrument, pinkish,
# Nearest to first: gatherer, poppers, charm, harmonisation, idi, swapped, discs, cuc,
# Nearest to were: congestive, collation, beloved, nicea, sapkowski, removes, shalom, grandmother,
# Nearest to d: sebasti, polonia, sissy, yates, nicol, censorware, pendleton, incest,
# Nearest to but: gears, lfflin, terabytes, bases, queens, tubular, dreamcast, sorel,
# Nearest to b: disenchantment, wretched, forseti, exon, defaulted, arena, franconia, tweed,
# Nearest to however: forwards, intuitively, pact, dowland, secessionist, prospective, restatement, lombok,
# Nearest to is: rally, astrophysics, londoners, faa, perfection, renaissance, pfc, victorians,
# Nearest to state: maroons, unicellular, fontana, rap, wakshul, grind, bibliotheca, audiogalaxy,
# Average loss at step 2000: 9.790188
# Average loss at step 4000: 5.821885
# Average loss at step 6000: 4.930698
# Average loss at step 8000: 4.544760
# Average loss at step 10000: 5.394123
# Nearest to years: dickinson, year, poetics, subscription, death, subsidiaries, rito, ngo,
# Nearest to during: in, on, amyl, cadr, blades, midian, probing, launches,
# Nearest to used: army, alternate, frau, love, chrysotile, asbestos, courtly, types,
# Nearest to he: she, it, who, macrobiotics, playoffs, endian, retarded, angie,
# Nearest to five: four, three, two, seven, eight, six, april, bligh,
# Nearest to no: gev, any, definite, masonic, seti, etna, cas, assimilation,
# Nearest to and: or, arcade, but, presupposes, typewriter, congestion, battered, noi,
# Nearest to use: way, history, course, field, covert, army, used, types,
# Nearest to first: recitative, same, greatest, bord, motivates, spectacles, racketeering, filius,
# Nearest to were: are, was, had, have, fast, chairs, purr, fullerenes,
# Nearest to d: army, history, alternate, love, asbestos, alaric, arius, courtly,
# Nearest to but: terabytes, which, illiterate, however, although, and, achieved, quaid,
# Nearest to b: hilda, barreled, addictive, andalusia, reddy, gneisenau, czechoslovakian, possessor,
# Nearest to however: contexts, frau, used, covert, industrially, courtly, herod, prostitution,
# Nearest to is: army, history, love, arius, field, d, means, alternate,
# Nearest to state: fontana, trend, alsatian, expire, bombs, aquarius, hovercraft, crockett,
# Average loss at step 12000: 3.955662
# Average loss at step 14000: 3.973387
# Average loss at step 16000: 3.987140
# Average loss at step 18000: 3.775126
# Average loss at step 20000: 3.546197
# Nearest to years: months, year, dickinson, helium, lifetimes, magee, consults, days,
# Nearest to during: in, over, after, throughout, against, through, on, within,
# Nearest to used: found, considered, called, known, referred, seen, given, required,
# Nearest to he: she, it, who, they, leiber, vj, ito, socialized,
# Nearest to five: six, four, three, seven, zero, eight, two, shamanism,
# Nearest to no: any, etna, callisto, lodges, dividend, been, rockefeller, stagnation,
# Nearest to and: or, but, excise, while, who, saarinen, although, fragmentation,
# Nearest to use: form, speak, stub, benson, napkin, sue, glasgow, criminology,
# Nearest to first: second, last, next, same, spectacles, moritz, greatest, looking,
# Nearest to were: are, was, is, became, being, rene, discard, shalom,
# Nearest to d: vries, ubu, decrees, flop, swells, gilbert, belgrano, b,
# Nearest to but: however, and, while, although, pollinator, than, altercation, sade,
# Nearest to b: army, courtly, asbestos, arius, frau, steiner, sydney, alternate,
# Nearest to however: but, although, while, though, that, pronounces, coms, stallion,
# Nearest to is: was, are, were, has, became, means, goldsmiths, makes,
# Nearest to state: bashar, anc, campus, fontana, amusement, hovercraft, formation, granted,
# Average loss at step 22000: 3.750955
# Average loss at step 24000: 3.635908
# Average loss at step 26000: 3.463158
# Average loss at step 28000: 3.423350
# Average loss at step 30000: 3.313098
# Nearest to years: days, months, decades, year, dickinson, times, seafood, centuries,
# Nearest to during: after, throughout, before, over, within, in, through, until,
# Nearest to used: considered, known, referred, seen, designed, found, held, represented,
# Nearest to he: she, it, they, bv, never, lumped, who, socialized,
# Nearest to five: six, seven, four, three, eight, zero, nine, two,
# Nearest to no: any, little, predestined, chandragupta, etna, commenced, only, another,
# Nearest to and: or, but, including, although, undetermined, fragmentation, with, piotr,
# Nearest to use: speak, suffice, belong, worthless, orderly, wear, nature, flirted,
# Nearest to first: second, last, next, same, greatest, earliest, original, final,
# Nearest to were: are, was, is, include, rene, became, being, confuse,
# Nearest to d: b, gilbert, pluralist, reddy, ubu, swells, rendition, flop,
# Nearest to but: however, though, and, although, see, jill, torpedoes, than,
# Nearest to b: c, n, d, nourished, nine, k, magdalena, industrious,
# Nearest to however: though, but, although, because, until, since, where, that,
# Nearest to is: was, are, became, includes, has, were, does, remains,
# Nearest to state: campus, speculative, government, ideology, picirilli, screening, qur, decade,
# Average loss at step 32000: 3.265810
# Average loss at step 34000: 3.474877
# Average loss at step 36000: 3.523571
# Average loss at step 38000: 3.338801
# Average loss at step 40000: 3.365216
# Nearest to years: months, days, decades, year, times, sorrow, lifetimes, dickinson,
# Nearest to during: after, in, before, within, despite, through, until, correspondents,
# Nearest to used: seen, written, known, found, considered, designed, represented, referred,
# Nearest to he: she, it, they, nourishment, lumped, ito, frideric, hajj,
# Nearest to five: six, eight, seven, four, zero, two, nine, reveal,
# Nearest to no: china, lough, shannon, frau, engl, narratives, dead, courtly,
# Nearest to and: while, or, but, although, including, undetermined, than, modest,
# Nearest to use: talk, wear, introduction, speak, belong, think, implement, produce,
# Nearest to first: last, next, second, throughout, sidewinder, waterway, tyrone, stake,
# Nearest to were: are, is, graves, chairs, was, include, be, have,
# Nearest to d: b, delicacy, courteous, guy, modulate, rc, rational, barnes,
# Nearest to but: although, and, while, see, however, than, or, kyushu,
# Nearest to b: d, p, beaufort, c, nourished, nightmare, belongings, trombone,
# Nearest to however: though, although, where, listeners, lough, scandal, erne, throughout,
# Nearest to is: was, are, has, became, includes, makes, remains, were,
# Nearest to state: electrification, anasazi, casing, hernia, government, supreme, photon, mimic,
# Average loss at step 42000: 3.367610
# Average loss at step 44000: 3.285508
# Average loss at step 46000: 3.322147
# Average loss at step 48000: 3.205341
# Average loss at step 50000: 3.142125
# Nearest to years: months, days, decades, year, times, hours, weeks, seconds,
# Nearest to during: throughout, before, after, in, until, within, since, when,
# Nearest to used: referred, seen, designed, known, considered, written, landholders, required,
# Nearest to he: it, she, hillel, baptism, nik, chapels, chrysotile, pigment,
# Nearest to five: four, six, three, eight, seven, two, zero, nine,
# Nearest to no: little, nothing, zarathustra, deportivo, chandragupta, faso, predestined, nutshell,
# Nearest to and: or, while, but, including, pleasuredome, like, vladivostok, although,
# Nearest to use: introduction, used, hco, speak, sense, rationing, belong, engage,
# Nearest to first: last, second, final, next, third, same, cosmetics, greatest,
# Nearest to were: are, was, is, have, being, had, rene, exist,
# Nearest to d: b, isosceles, k, loma, escorial, drip, morava, initialism,
# Nearest to but: while, although, though, and, than, however, kyushu, or,
# Nearest to b: d, loma, bertha, dp, ceylon, pavel, reddy, embassy,
# Nearest to however: although, while, though, but, that, bonfires, since, where,
# Nearest to is: was, are, makes, became, includes, remains, contains, becomes,
# Nearest to state: city, branch, meander, team, authorship, luzon, government, colonialism,
# Average loss at step 52000: 3.201058
# Average loss at step 54000: 3.250996
# Average loss at step 56000: 3.072724
# Average loss at step 58000: 3.166690
# Average loss at step 60000: 3.245244
# Nearest to years: months, days, decades, times, weeks, year, centuries, hours,
# Nearest to during: throughout, after, before, in, within, despite, at, since,
# Nearest to used: seen, referred, considered, known, designed, defined, required, written,
# Nearest to he: she, it, they, lumped, leiber, hark, who, faire,
# Nearest to five: four, six, seven, eight, three, nine, zero, two,
# Nearest to no: a, little, any, nothing, only, paradoxes, zarathustra, bedtime,
# Nearest to and: but, although, while, including, or, though, than, however,
# Nearest to use: belong, introduction, speak, describe, form, need, apply, flirted,
# Nearest to first: last, next, second, earliest, final, third, original, belly,
# Nearest to were: are, was, is, audita, exists, include, gur, geographer,
# Nearest to d: b, criticizes, usgs, barnes, widows, rope, de, pluralist,
# Nearest to but: and, although, however, than, though, see, kyushu, rationalism,
# Nearest to b: asbestos, rotors, alternate, courtly, mountain, q, dublin, albinism,
# Nearest to however: although, though, but, while, that, since, which, where,
# Nearest to is: was, are, has, becomes, became, makes, exists, includes,
# Nearest to state: colonialism, picirilli, cellular, luzon, convict, definition, usa, mimic,
# Average loss at step 62000: 3.321986
# Average loss at step 64000: 3.217926
# Average loss at step 66000: 3.246772
# Average loss at step 68000: 3.158365
# Average loss at step 70000: 3.308902
# Nearest to years: months, decades, days, year, weeks, hours, times, minutes,
# Nearest to during: in, throughout, at, despite, after, before, until, through,
# Nearest to used: seen, designed, referred, required, introduced, found, considered, employed,
# Nearest to he: she, it, spandau, transmitting, circuitry, they, who, nourishment,
# Nearest to five: six, seven, four, three, zero, eight, two, agm,
# Nearest to no: bedtime, narmada, gev, marseilles, refuting, waterfalls, lodges, destined,
# Nearest to and: while, but, including, or, although, steppenwolf, though, when,
# Nearest to use: speak, introduction, using, need, flirted, study, hco, belong,
# Nearest to first: last, second, next, earliest, third, best, cosmetics, same,
# Nearest to were: are, erne, maniac, randi, manipulate, lynx, cathodes, rump,
# Nearest to d: b, starters, caer, prix, frac, criticizes, cryopreservation, pacifica,
# Nearest to but: although, and, though, however, while, than, which, lambasted,
# Nearest to b: d, dimensional, direct, prix, frey, flats, sdp, zaragoza,
# Nearest to however: although, though, while, but, since, when, because, stag,
# Nearest to is: was, are, makes, becomes, remains, became, has, includes,
# Nearest to state: colonialism, government, luzon, picirilli, allah, trainees, detrimental, maclaurin,
# Average loss at step 72000: 3.191991
# Average loss at step 74000: 3.141743
# Average loss at step 76000: 3.248812
# Average loss at step 78000: 3.227091
# Average loss at step 80000: 2.983265
# Nearest to years: months, decades, days, year, weeks, hours, times, centuries,
# Nearest to during: in, throughout, before, despite, after, until, since, through,
# Nearest to used: seen, designed, found, required, referred, applied, employed, available,
# Nearest to he: she, it, they, leibniz, athlon, leiber, there, lumped,
# Nearest to five: seven, four, six, three, eight, zero, nine, asians,
# Nearest to no: any, diaz, little, anyone, destined, waterfalls, nothing, lodges,
# Nearest to and: or, including, etc, while, steppenwolf, vladivostok, however, although,
# Nearest to use: geeks, dublin, lough, cathodes, erne, feces, flashing, rump,
# Nearest to first: last, next, earliest, third, second, same, fourth, original,
# Nearest to were: are, was, affects, complementing, clipperton, randi, adolphus, geeks,
# Nearest to d: rudolf, hallstatt, opulent, barnes, starters, rc, l, reddy,
# Nearest to but: although, however, though, see, because, than, or, and,
# Nearest to b: geeks, courtly, albinism, asbestos, lough, dublin, pitts, rump,
# Nearest to however: although, but, while, though, because, that, where, since,
# Nearest to is: was, makes, are, becomes, has, includes, represents, contains,
# Nearest to state: government, colonialism, luzon, cellular, submissive, convict, oregon, athelstan,
# Average loss at step 82000: 3.030616
# Average loss at step 84000: 2.975817
# Average loss at step 86000: 3.051813
# Average loss at step 88000: 3.027503
# Average loss at step 90000: 2.928043
# Nearest to years: months, decades, days, weeks, year, times, seconds, hours,
# Nearest to during: in, after, within, throughout, until, at, over, before,
# Nearest to used: designed, employed, referred, seen, applied, available, found, written,
# Nearest to he: it, she, they, leibniz, lumped, colon, eider, ito,
# Nearest to five: four, eight, seven, six, three, zero, nine, two,
# Nearest to no: little, nothing, several, also, any, predestined, zarathustra, nutshell,
# Nearest to and: while, or, though, including, although, however, but, slovakian,
# Nearest to use: speak, introduction, list, amount, form, study, using, flirted,
# Nearest to first: last, second, earliest, next, best, greatest, fourth, original,
# Nearest to were: complementing, geeks, erne, heap, randi, cathodes, lough, binary,
# Nearest to d: b, l, logographic, progs, superpower, prix, collar, wolf,
# Nearest to but: however, although, though, see, and, than, pollinator, quaid,
# Nearest to b: d, analyzer, j, cornell, eisenman, subnational, dimensional, topology,
# Nearest to however: but, although, though, while, and, since, during, satisfies,
# Nearest to is: was, are, remains, represents, exists, becomes, makes, has,
# Nearest to state: luzon, cellular, mimic, newfoundland, michigan, salomon, ra, sketch,
# Average loss at step 92000: 2.946113
# Average loss at step 94000: 2.956127
# Average loss at step 96000: 2.759073
# Average loss at step 98000: 2.643989
# Average loss at step 100000: 2.783696
# Nearest to years: months, days, decades, weeks, hours, year, minutes, times,
# Nearest to during: throughout, despite, in, at, over, until, after, within,
# Nearest to used: required, invented, adopted, designed, administered, held, attributed, referred,
# Nearest to he: she, they, it, who, athlon, faire, leibniz, spandau,
# Nearest to five: heap, lough, geeks, rump, dublin, druids, heapsort, ternary,
# Nearest to no: little, any, nothing, always, zarathustra, mortals, callisto, ciphertexts,
# Nearest to and: or, but, while, including, steppenwolf, scolded, etc, however,
# Nearest to use: introduction, production, study, speak, amount, practice, form, flirted,
# Nearest to first: last, second, next, earliest, third, best, greatest, longest,
# Nearest to were: are, was, include, is, being, have, had, contain,
# Nearest to d: crews, b, couplet, pitts, ehud, encased, binary, particles,
# Nearest to but: however, and, although, despite, while, than, see, though,
# Nearest to b: d, hegelians, overwhelm, beetles, procreation, stalled, crosstown, unloaded,
# Nearest to however: although, but, despite, though, while, that, since, because,
# Nearest to is: was, are, exists, makes, remains, represents, provides, contains,
# Nearest to state: michigan, states, sketch, monarchist, luzon, defence, athelstan, ghats,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
    assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
    pylab.figure(figsize=(15,15))  # in inches
    for i, label in enumerate(labels):
        x, y = embeddings[i,:]
        pylab.scatter(x, y)
        pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
    pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)

# %% [markdown]
# Some clusters are less obvious (like the standalone characters), but it clearly totaly works!

# %% [markdown]
# How does your CBOW model perform compared to the given Word2Vec model? (to be answered)

# %% [markdown]
# At the first sight, they look similar. The CBOW is a more compact.
